# %%
# !pip install pdfplumber
import pdfplumber
import pandas as pd
import re
# Out:
# Requirement already satisfied: pdfplumber in c:\users\maseglo.com\anaconda3\lib\site-packages (0.11.7)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\maseglo.com\anaconda3\lib\site-packages (from pdfplumber) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\maseglo.com\anaconda3\lib\site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\maseglo.com\anaconda3\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\maseglo.com\anaconda3\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\maseglo.com\anaconda3\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\maseglo.com\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\maseglo.com\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.21)

# %%
pdf_path = "Urhobo_Dictionary_by_Ebireri_Okrokoto_Ur.pdf"

# %%
with pdfplumber.open(pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        text = page.extract_text()
        if text:
            print(f"\n--- Page {page_num + 1} ---\n{text}")
# Out:
# --- Page 1 ---
# U R H O B O TO E N G L I S H
# D I C T I O N A R Y
# by
# EBIRERI OKROKOTO
# URHOBO LANGUAGE INSTITUTE
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ===================================================================
# TONE MARKS (FOUR IN ALL) d , r , m ,
# ~
# 1. ( `) d for lowered voice : Has a short stroke pointing left.
# 2.(ˊ ) m for raised voice : Has a short stroke pointing right.
# 3. ( ) Slur for drawing the voice on the sound of the vowel
# ~
# and is represented by a wave-like mark on such vowel.
# 4.( ) nothing is for flat tone that represent middle voice.
# ============================================================= =====
# THE ALPHABETS
# A B CH D DJ E Ẹ F G GB GH GHW H HW I J K KP L M N O ọ
# P PH R RH S SH T U V VW W Y Z ( VOWELS= A E Ẹ I O ọ U )
# 1
#
# --- Page 2 ---
# A
# URHOBO WORDS ENGLISH MEANING
# Abaka…………………… Grasshopper
# Abe……………………… A species of water yam with red
# colored leaves and tuber
# Abe……………………… Guilty verdict
# Abo……………………….. Wrestling. Also means HANDS - plural form
# for hand called Ob
# Abotu……………………. Group effort
# 2
#
# --- Page 3 ---
# Abamwa……………….. Rag ; torn piece of cloth
# Ada……………………….. Outing ; out from home : Kpẹ ada = gone
# Out from home ; Short trip from home.
# Adja …………………….. Bat
# Adjudju…………………… Hand-held fan usually made from animal skin
# Afiotọ………………………. Giant African rabbit
# Afọrhe……………………… Brain
# Agbada……………………… Bridge
# Agbagba………………….. Cross
# Agbara…………………….. Chair
# Agbariko………………….. King fisher
# Agbogu……………………. Dagger
# Agboro…………………….. Radio ; echo
# Agbotọ……………………… Jaw
# Agbuna…………………….. Matches
# Agh……………………….. Branch
# Aghgh……….......... Joy
# Aghwaghwa………. Bush dog ( a nocturnal, tree climbing animal )
# Aghwoghwo…………… Announcement
# Agogo………………………. Bell ; Gong
# 3
#
# --- Page 4 ---
# Aha ! …………………….. A shout of surprise
# Ahanre (also called IKPEKPA )……Lower deck of fireplace platform.
# Ahe………………………………… Night owl
# Ahwa……………………………….. A beaked non climbing giant squirrel
# Aka…………………………………… Edo people from southern Nigeria
# Áká………………………………….. Bitter kola
# Akaunọrọ……………………. Lizard
# Ako…………………………………… Tooth
# Akoroda……………………………. Cutlass sheath.
# Akpãkpa……………………… Mat woven out of palm branch back
# Akpakpasimagha ……………… Scorpion
# Akpanurhe…………………………. Local Low seat
# Àkp
# é
# rẹ̀…
# …………………… Bull horn
# Akpẹ …………………….Padlock ; Bird’s gizzard ; container of items
# Akpẹrẹ………………… Basket
# Akpẹtẹ…………………. Chief cook ; cook
# Akpine…………………. Lead singer
# Akpọ…………………… World ; earth ; life
# Akpono………………… Plastic beads for female fashion.
# Ame……………………. Water
# 4
#
# --- Page 5 ---
# Amiedi………………… Palm oil soup
# Amirika………………. Ethanol ; drinkable alcohol .
# Anama……………….. Show off ; stylish ; proud
# Anurhoro……………. Entrance to a house or room ; doorway
# Apata………………… Unauthorized release of someone else’s
# information ; revealing other’s secrets.
# Aphia………………… Knife. ( also called Avwia )
# Aphopho……………. Breeze
# Aranto………………. Small ant hill with a hat-like top cover.
# Are…………………… Razor blade ( also known as Erakivẹ̣̣ )
# Areba……………….. A poisonous wild garden egg plant .
# Arhare………………. Forehead
# Arh …………………. Salvation ; Having life
# Arhọghọ……………. Contribution
# Arirhiri…………….. Tortoise; name indicative of its crafty behavior.
# Ariri……………………….Fish net
# Arodọvwẹ ………… Pity ; Mercy
# Aruvwẹ……………. Dawn ; daylight period.
# Asa………………... Place
# Asakuẹ……………. Multiplied by .
# Asé…………………. Non guilty verdict ; Acquittal
# Aso…………………. Night
# Atarhe…………….. Pre- destination
# 5
#
# --- Page 6 ---
# Atẹtẹ………………. A seller/hawker’s ware display platform
# Ato…………………. Desert
# Ató…………………. Chewing stick.
# Avwebọ…………… Favorite person
# Avwro………………. Argument ; Expression of a second opinion.
# Awanre……………… Ancient
# Ayar  …………………….Fish trapping basket
# Aye………………… Woman
# Azagba…………… Presence of everyone; un- hidden ;
# In front of an audience.
# B
# Baba ………………. Father
# Bẹnẹ……………….. Romance
# 6
#
# --- Page 7 ---
# Bẹre ………………… Tear
# Beroma……………. Lament in despair
# Bẹsiẹye ……………. Until then ; Until that time
# Biebi……………….. Black
# Bio…………………… Push
# Biko…………………. Please ; I beg you
# Bioma…………… Excuse me ; get out of my way
# Bitoboyi………Dress there ;Excuse me ; move there
# Bọ……………………….. Build
# Bov………………………….. Where ?
# Bra………………………………… Bad
# Brabra…………………………. Very bad
# Branama…………………….. Display style ; Proud ; Show off.
# Brẹdẹ ………………………… Make an appointment date.
# Brigho ………………………. How much is the price tag ?
# Brisẹ……………………… Add a “Proverb” ; Clarify with a proverb.
# Bro……………………………… Cut it.
# Bró……………………………… How many ?
# Broma………………………… Hurry up ; Walk fast.
# 7
#
# --- Page 8 ---
# Bruche ……………………….. Advise
# Brudu ………………………… Worry
# Buebu………………………… Many ; Plenty ; a lot.
# C H
# Chá………………… Support ; Add to it ; augment.
# Cha…………… Coming e.g. Mẽ cha = I am coming.
# Chere……………………… Cook
# Chirako……………………. Endure
# Cho…………………………. Steal
# Choja………………… Avenge a long time grudge.
# Choma ……………… Be prepared ; Get ready.
# Chuji…………………. Steal
# Chuko……………… Help ; Lend a hand ; Support.
# Churo……………… Tie it
# 8
#
# --- Page 9 ---
# D
# Da………………………………… Drink
# Dame……………………………. Drink water
# Dẽdè……………………… Welcome
# Dedé…………………….. Welcome him/her.
# Davwe…………………… Try ; Test
# Davw……………………………….. Test it ; Try it.
# Dẹ…………………………… Buy
# Dẹ́dẹ́……………………….. Gently (also Dẹ́ẹ́dẹ́).
# Dedẽde…….Without fear ; Without discrimination.
# Didiemu ?.................... What is it ?
# 9
#
# --- Page 10 ---
# Die ? ………………………… What ?
# Dierhare……………… Warm up around fire.
# Diguẹ………………… Greet with knees down or bent .
# Divwi……… Sink ; Dive ;(divwi ame = dive into water ).
# Do………… Greeting ; An elder greeting his junior.
# D’udi……………………. Drink liquor ( da udi ).
# DJ
# Dja………………………………………Spicy ; Pepper-like taste ;
# Hot painful feeling
# 10
#
# --- Page 11 ---
# Djadja……………………………………Very hot and spicy ; Very
# hot painful feeling
# Djẹ……………………………………….Run
# Djonẹ……………………….
# Run a race
# E
# Ebo…………………………………….Local woven package bag
# Eb…………………… House roofing with attached leaves
# 11
#
# --- Page 12 ---
# Ebri……………………………………Darkness
# Ebruba………………………………Blessing
# Edi……………………………………Palm tree fruit
# Edja…………………………… Helminths ; Parasitic worms
# Edje………………………………… Mates ; Equals
# Edjere……………………………… Crocodile
# Efe………………………………….. Riches
# Efi…………………………………… Palm tree climbing rope
# Efia…………………………………. Lie
# Egbn…………………………… Bullets
# Egẹnẹ
# …………………………...Bullets
# Eghwa…………………………… .Load
# Eghwughwẹ……………………. Chameleon
# Egedege………………………… Multiple floor building
# Eha………………… Play
# Eheri………………. Fashion
# Eho…………………… Fine ; Consequence of a guilty verdict.
# Ejọ̃rọ…………………. Metal chain
# Ehuhu………………… Armadillo ; Pangolin
# 12
#
# --- Page 13 ---
# Eka……………………. Curse
# Ekanaka……………… Breakable Plate
# Eki……………………. Market
# Ekogho……………… Area ; Neighborhood
# Eku… Oppression ; Subjection (through false allegations)
# Ekpẹ……………………… Soil ; Sand
# Ekpeti ………………..Box
# Ekpu…………………. Pocket
# Ekrirhe………………. Bundle of firewood
# Ekrirhekrẹbe………. Silk Worm
# Ekru…………………… Bundle
# Ékru…………………Family
# Émámọ
# …………….. Fruit
# Emamọ……………… A good one
# Emeravwe………… Moon ; Month
# Emeraravwe…….. Ant
# Emu…………………. Food
# Enanadja………….. Pineaple
# Eni…………………… Elephant
# Ení…………………… Protective bunch of clothes
# or materials put between head
# 13
#
# --- Page 14 ---
# and load for cranial safety.
# Enu……………….. Up
# Epha……………… Oracle
# Epharo…………… Face
# Ephẹ……………… Urine
# Ephẹrẹ………….. Language
# Eravwe………….. Animal
# Erere…………….. Profit
# Erha………………. Three
# Erhare…………... Fire
# Erhi……………….. Butterfly
# Erhie……………… Grains of paradise ; Alligator pepper
# Erhivwi…………… Millipede
# Erhọ……………….. Ear
# Erhu………………. Hat
# Erhuẹ…………….. Cow
# Erhurhu…………… Garbage dump
# Erhuru……………. Shore ; Beach ; River’s edge
# Erhuvwu…………. Beauty
# Eri…………………... Fish
# Ésẹ́……………… Scale (e.g. fish scale )
# 14
#
# --- Page 15 ---
# Esha…………… .. Grey hair
# Eshẹ…………..
# Rash ; skin complaint
# Eshe……………… The Fall of…… ; Fall
# Esi…………………… Pig
# Esia…………………. Fable
# Eshu……………….. Devil
# Eto…………………. Pumpkin
# Evu………………… Stomach ; Belly
# Ẹ
# Ẹba…………………………….. Nakedness
# Ẹba…………………………………….King fish
# 15
#
# --- Page 16 ---
# Ẹbe…………………………….. Leaf ; Book
# Ẹchẹ……………………………………… Door
# Ẹdẹ………………………………….. Day
# Ẹdidjana ( otete )…………. Saturday
# Ẹdidjana ( orode )………….Sunday
# Ẹdiruo…………………………….Weekday ; Work day
# Ẹdẹfa………………………………. Another day
# Ẹdeki…………………………… Market day
# Ẹdorẹ………………………………..Festival day
# Ẹdevwiẹ………………………. Birthday
# Ẹga………………………………. Service
# Ẹga……………………………… Barren ; Childless person
# Ẹghware…………………… Wisdom ; Sense
# Ẹghwẹre……………………… Mat
# Ẹghweya…………………. Women folk
# Ẹghwọ…………………… Quarrel ; Misunderstanding
# Ẹgua ……………………. Defilement
# Ẹguare…………………… Court
# Ẹguọnọ…………………… Love ; Affection
# Ẹho……………………….. Nest ; Bird’s nest
# 16
#
# --- Page 17 ---
# Ẹhọ́……………………….. Bathing
# Ẹhọnimuemu…………... Baptism
# Ẹjẹ (Ẹsanọ)…………… Selection
# Ẹjo………………………… No ! ; Not at all
# Ẹkẹ…………………………… Portion
# Ẹkẹrẹkẹtẹ………………….. An Ass
# Ẹkẹvuọvo…………………. But ; although
# Ẹkegba……………………… Rust
# Ẹkihwe……………………… one tenth (
# 1/10 )
# Ẹkpa ………………………… Foolish ; Unripe
# Ẹrhé……………………… Sea cow ; Manatee
# Ẹrhia…………………………. Disclosure of people’s
# Secrets ; Tale-bearing
# Ẹrho……………………….. Cat-fish
# Ẹrhorho………………….. Leech
# Ẹrhoro…………..Tip of the germinating plant
# Ẹrhovwo…………………… Prayer
# Ẹro…………………………… Eye
# Ẹrẹvwe…………………………. Tongue
# Ẹsanọ (Ẹjẹ)………………….. Selection
# 17
#
# --- Page 18 ---
# Ẹse…………………………, Gift
# Ẹsọ………………State of penury ; Abject poverty
# Ẹsosuọ……………………… First ; Beginning
# Ẹto…………………………… Hair
# Ẹvwé…………………………. Goat
# Ẹvwe………………………… Kola nut
# Ẹvwẹrẹ…………………….. Clay pot
# Ẹvwẹ́re……… Food that’s boiling/cooking on fire
# F
# Fa…………………………. Flog
# 18
#
# --- Page 19 ---
# Fa………………………… . Kick ( e.g. Ball )
# Fa………………………… .Reveal (e.g. Cause ) ; Expose
# Faro……………………… Intolerant ; Hash
# Frae……………………, Light weight
# Fe………………………….Get rich (efe = riches )
# Fẹnẹ…………………… Discriminate ; Different from.
# Fẹrẹ………………….. Flip ; Flip it
# Fia……………………… Cut off with a single strike
# (e.g. with machete or sword)
# Fia ……….………….. Change; Reduce to smaller
# units (e.g. money)
# Fiabọ………………… Empty handed
# Fiẹ…………………. Leak (e.g. Uko fiẹ= Cup leaks)
# Fiọ…………………….Sneeze it out
# Fiọfiọ………………….Leak and suck
# Fiunu………………. Hiss
# Foma………………….Confess one’s misdeeds
# Foma………………….Payment of travel fare
# Fọ………………………Wait
# Fọrhọ………………….Wash ( e.g. wash Cloth)
# 19
#
# --- Page 20 ---
# Fro…………………… Snatch it
# Fronẹ……………….. Race off; Run away
# Fru………………….. Snatch
# Fuafo………………… White
# Fue…………………… Stop it
# Fuefu………………. Gentle
# Fuẹrẹ……….Scrutinize ;Carefully examine ; research
# Furhie…………………Quench ; put out fire
# G
# 20
#
# --- Page 21 ---
# Ga………………………..Serve ; Worship
# Gaga…………………… Strong ; Hard
# Gẹrẹ………………….. Slant it ; Bent
# Geri…………………… Vomit
# Gidigba………………. Very big ; ( adj. showing size.)
# Gò…………………….. Gloat ; Boast
# Godogodo…………… Seldom
# Gogo…………………. Publish ; Display
# Gogorogo…………… Very tall ; Very huge
# Goma…………………. Strong
# Grogro…………………Tall
# Gu……………………. Make a statement
# Gua…………………… Drive
# Guegue……………… Frighten
# Gugunu……………… Not straight
# Gugurugu…………….Huge amount
# Guma………………… Big
# 21
#
# --- Page 22 ---
# GB
# Gba………………………. Tie
# Gbagbá…………………..Correct
# Gbane…………………… Hug
# Gbe………………………. Dance
# Gbeha………………….Dance
# Gbegbé………………..Dirty ( also Gbe )
# Gbesia………………..Tell fables
# Gbẹ…………………… Clear weeds ; un-weed with cutlass
# Gbẹkẹ……………. ….Full to the brim ; a lot (e.g.) of food
# Gbiẹyi………………..Dead silent
# Gbiku………………..Tell story
# Gbo…………………. Smell
# 22
#
# --- Page 23 ---
# Gbo………………….Search for rummages ; Looking around
# trees for their fallen edible fruits
# Gbogbo……………………… Rotten
# Gboma………………………. Dance joyfully
# Gbraka………………………. Big and robust
# Gbrẹrẹ………………………. Medium size ; average shape
# Gbunie………………………. Rolling on the floor ; Sign of
# humility. (Who’s down fears
# no fall ; fears no pride)
# Gbunu………………………. Fasting ; Abstinence from food
# 23
#
# --- Page 24 ---
# GH
# Gha……………………. Forbid
# Gha……………………. Open up e.g.( Umbrella or eye
# glass)
# Ghare…………………. Divide
# Ghare……………….. Expensive
# Ghẹrẹ………………… Nurture a child ; Up bringing ; Nourish
# Gho……………………. Hoot him/her
# Ghoro………………… Roam ; Moving around without
# Destination . A hawker’s aimless trip
# Ghọ………………….... Presenting kola nut and money
# to entertain and celebrate a
# visitor’s arrival.
# Ghọghọ………………. Rejoice
# 24
#
# --- Page 25 ---
# GHW
# Ghwa…………….. Carry
# Ghwá………Gift for good performance e.g. dancing
# Ghwẹ̣……...Pack stuff with palm of your hands
# Ghwiẹ…̣ …Fold up (e.g.) sun-dried clothes ; Slap
# him/her
# Ghwie……………………….. Uproot
# Ghwo………………………… Old ; Ripe
# Ghwoghwo………………… Announce
# Ghworo……………………. Rub
# Ghworiẹ…̣ …………………. Slippery
# Ghworiẹ́…………………….. Rinse
# Ghwọ̣…………………………..Quarrel ; Scold
# Ghwọghwọghwọ………. .. Un-sanitary ; Filthy
# Ghwọrọ̣………………………..Roam in a road less bush or
# Forest
# Ghwọrọ̣……………… Waste (ghwọrọ kufia =waste away)
# Ghwu…………………………. Die
# 25
#
# --- Page 26 ---
# Ghwru………………………….Lost ; Cannot find
# H
# Harhọ……………………….. Blame him/her
# 26
#
# --- Page 27 ---
# Heha………………………… Play
# Hẹrhẹ………………………. Wait
# Hiẹ…̣ ………………………. Dig in ; Scramble
# Hirhe……………………… Detour ; Return
# Họhọhọ………………….. Heavy
# Họhọ̣re………………….. Look alike
# Họrhọ…………………… Boil
# Hra………………………. Scatter ; undo the orderliness
# Hrahrọ…………………. Apply evenly ; Spread equally
# Hrohro…………………. Scratch out the last remnant
# HW
# 27
#
# --- Page 28 ---
# Hwa………………………… Pay
# Hwahwá………………….. Narrow
# Hwe………………………… Beat ; Punish ; pummel
# Hwẹ…………………………Laugh
# Hwehwa………………….. Make a bed
# Hwehwẹ…………………… Laugh
# Hwihwirihwi…………….. Very dark ; More than black
# I
# 28
#
# --- Page 29 ---
# Ibaba………………………Father
# Ibẹfi………………………Hunting
# Ibehre………………….. Mud
# Ibi…………………………..Charcoal
# Ibivu……………………… Intestine
# Ichabọ……………………. Assistant
# Ídjédje………………….. Explanation
# Idjerhe…………………… Road
# Ifọ…………………………. Vegetable ; Water leaf
# Igberadja………………. Prostitute
# Igede…………………… Drum
# Igoni……………………. Handcuff
# Igbigbi…………………. Pretence ; Faking
# Igbunu…………………. Miracle
# Igho…………………….. Money
# Ikọhọ…………………… Egg
# Ikpekpa……………….. Platform over the fireplace
# Iku……………………… Crawfish
# 29
#
# --- Page 30 ---
# Iku……………………… Story
# Ine……………………… Song
# Inene…………………… Mother
# Inuhu…………………… Dirt
# Ipẹrẹ…………………… Nail
# Iporoma………………. Sword
# Ipọtọ…………………… Button
# Irhe……………………. Wood
# Irho……………………. Dew
# Iroro………………….. Thought ; To think
# Iruo……………………. Work
# Isa…………………….. Ring
# Isẹ…………………….. Proverb
# Isha………………….. Beans
# Ishasha………Small seeds like alligator pepper from a
# Climbing plant, used as a stimulant/herb
# Ishu………………….. Lice
# Isi…………………….. Multitude of people
# Isio…………………… Star
# Isọ……………………. Excreta
# 30
#
# --- Page 31 ---
# Itẹ……………Proverb directed at a specific person
# Itu…………………….. Mushroom
# Ivwri…………………. Fat ; Animal/ Fish fat
# Ivwri………………… Tailor Ant
# Iyesi…………………. Horse
# Izegede……… Unfinished building ;Un-completed,
# Door-less house.
# J
# 31
#
# --- Page 32 ---
# Je……………………………. Admire ; Like
# Jẹ……………………………. Pick ; Selecting in turns
# Jio………………………….. Send him/her
# Jiro…………………………. Praise him
# Jokpa……………………… Except ; Unless
# Jovwo…………………….. Do not proceed ; Discontinue
# Jurhi………………… Proclaim an edit ; Make a law or regulation
# K
# Kaka……………………………… Not at all
# Karohọ……………………
# Remember ; Do not forget
# Kẹ́…………………………………. Give
# Kẹkẹrẹkẹ……………………. Portable ;Medium shape size
# 32
#
# --- Page 33 ---
# Ken………………………….. Sour
# Kerhọ
# ……………………… Listen
# Kẹvwẹ………………………….. Give me
# Kio ( eg Kio riariẹ )… Go round ; wrap it round
# Ko………………………….. Sew ( with a sewing machine )
# Kọ………………………….. Sow ( sow a seed )
# Koka………………………. Make a mark
# Koko……………………… Gather
# Kokoroko………………. Very strong
# Krekri……………………. For a long time
# Krẹkrẹ…………………….. Short
# Kri………………………... Late arrival or late departure
# Kro……………………….. Bundle it up
# Kru……………………….. Bundle it up
# Kuakó……………….. …. Stunted growth
# Kueku ………………….. Cheap
# Kuo…………………… …. Pour
# 33
#
# --- Page 34 ---
# KP
# Kpaikpai……………All and leaving nothing behind
# Kpatakpata……………….Quickly
# Kpẹ………………………….Peel
# Kpẹhrẹ………………………Small ; Not tall
# Kpẹkpẹrẹkpẹ…………… For ever
# Kperi……………………. Shout
# Kprekpre…………………Forceful push ; Series of
# sudden pushes.
# Kpo………………………. Go home
# Kpogho………………….. Shake
# Kporo…………………….Break down ( e.g. of a wall)
# Kprẹsẹ…………………….Dwarfish stature
# Kpuhru………………… Short ; Describing how short
# 34
#
# --- Page 35 ---
# L
# THIS ALPHABET IS USUALLY REPLACED BY
# N
# EXCEPT IT APPEARS IN THE MIDDLE OF A
# WORD. EXAMPLES : SAPELE AND PỌLỌKO ̣
# NỌKỌNỌKỌ ………… An adjective describing skin texture
# ( Lọkọlọkọ) and/or a well nurtured person.
# 35
#
# --- Page 36 ---
# M
# Mama…………………………..Mother
# Mamọ………………………….Genuine one ; Good type
# Mẹ………………………… Me
# Mẹvwẹ…………………… I am
# Miavwa…………………. Painful
# Miẹmiẹ …………………. Sweet
# Mio………………………. De-water ; Squeeze water from…
# Mọ…………………… ….. come
# Momo……………………. Borrow
# Mra……………............. Sound
# Mragha…………………. Bluffing ; Showing off
# Mraro…………………… Telling the future ;
# Devine prediction ; Prophecy
# Mrẹ………………………. See
# 36
#
# --- Page 37 ---
# Mrorẹ……………………. Can see
# Muo……………………… Carry
# Muọga…………………… Sick
# N
# Nanãna………………………………… Now
# Ne………………………………………… Pass feces
# Nene…………………………………… Mother
# Nie……………………………………… Take
# ………………. i
# Nó Look at t
# Nọ………………... Ask
# Nomaso…………..Attention ; Take Note ; Beware
# 37
#
# --- Page 38 ---
# Nonẹ………….
# Today
# O
# ó
# ba……………………… End
# Obọ………………………. Hand
# Ochẹ………………………Clay drinking water storage pot
# Oda…………………….… Cutlass
# Odjadja…………………. Suffering ; Painful experience
# Odjuvwu…………………. Heaven
# Ofe…………………………Yam beetle
# 38
#
# --- Page 39 ---
# Ofefe……………………… Empty
# Ofia…………………… Lie
# Ogaga…………………… Strength
# ógba………………………… Fence
# Ogba………………………… Oil seed
# Ogbo…………………………. Boa ;Python
# Ogbru………………………….The male’s big wrapper dress cloth
# Ogidi……………………… Violence ; Rowdiness
# Ogiribo……………………… .Storm
# Ojuvwu…………………. Heaven
# Oka……………………………..Style
# Óka…………………………… Mark
# Okẹ…………………………… Gift
# Oko……………………….. Friend
# ókpa……………………… A thick locally woven cloth
# Òkpé…̣ ………………………………. Stingy ; Miserly
# ó
# kpẹ……………………. A dialect of Urhobo language
# Okpitẹ……………………………. The person who speaks in proverbs
# Okri…………………………. Male goat
# 39
#
# --- Page 40 ---
# Oma……………………….. Body
# Óma………………………. Statue
# Ona………… Solution finding ; Craftiness ;Shortcut art ; Trick
# Oni…………………………………Mother
# Ora……………………………… ..Sore
# Orẹ………………………………………… Feast
# Orhare…………………………………… A Well
# Orhirhi…………………………………… Electric fish
# Orho ……………………………………… Town ; City
# Orhua…………………………………… Deer
# Orhuẹ………………………………….. Hunter
# Orhuẹre ………………………………. A species of catfish
# Orí………………………………………...Lotion
# Órí…………………………………………Processed corn starch meal
# Oro……………………………………….. Gold
# Oruru…………………………………….Cotton thread
# Osa………………………………………. Debt
# Ósa……………………………Rectangular woven basket for loads
# 40
#
# --- Page 41 ---
# Osiẹbe………………………………… Clerk
# Osio…………………………………….. ………….Rain
# Osu…………………………………….. ………….Ruler ; Governor
# Ota……………………………………… ………….Speech
# Oti…………………………………………………..Leprosy
# Otọ…………………………………………………Ground
# Owọ………………………………… …………..Leg
# Ọ
# Ọbara………………………………………… Blood
# Ọbo ………………………………………….. Native doctor
# 41
#
# --- Page 42 ---
# Ọboba……………………………………….. Young ; Not mature
# Ọdafe………………………………………… Rich person
# Ọdọ………………………………………….. Beetle’s larva
# Ọfẹ……………………………………………. Tilapia
# Ọfigbo………………………………………. Palm oil
# Ọgá…………………………………………… Master
# Ọgá
# …………………………….. Animal track
# ọ̀
# gà…………………………………………… Sickness ; Disease
# Ọgọdọ………………………………………Pit
# Ọgọrọ………………………………………Palm wine
# Ọka………………………………………… Corn
# Ọke ………………………………………… Period of time
# Ọko………………………………………….. Gift parcel ; Present
# Ọkó……………………………………………. Village
# Ọkpako…………………………………..Older person ; More elderly
# Ọkpó…̣ ……………………..A species of the lizard
# Ọkpó…̣ …………………………...Pole ; Walking stick
# Óḳ pọ………………………..Name sake
# 42
#
# --- Page 43 ---
# Ọmọ………………………………………… Child
# Ọmọhọ……………………………………. Baby chick
# Ọmọphra………………………………… Bird
# Ọmọshare ……………………………… Boy ; Son
# Ọmọtẹ……………………………………… Girl ; Daughter
# Ọpuọpuọ………………………………… Shark ; Stinging ray fish
# Ọre…………………………………………. Sun
# Ọrhare…………………………………….. Chronic bachelor ;Male
# without the means to
# afford a marriage patner.
# Ọrharha…………………………………. Stranger
# Ọrigbẹ………………………………..Porcupine
# Ọrigbo……………………. ……….Bitter leaf ;Bitter leaf plant
# Ọrọdekọ……………………………… Snake
# Ọsẹ……………………………….Father
# Ọshare………………………….Man
# Ọso……………………………… Hawk
# ọ
# suke………………………….Hunch-back
# Ọtota……………………………Spokesperson
# 43
#
# --- Page 44 ---
# Ọyọn…………………………….Honey
# P
# Patiẹn………… Flat ; Deflated ; ( Evu patiẹn = Flat tummy)
# Pẹtẹpẹtẹ……(adj) Watery and soft ; Word describes
# wetness or dryness e.g. of gari,
# Soil, effect of water on surface etc.
# Piẹ̃piẹ̃……(adj) Just forming ; Young ; immature ;unripe.
# Word : describes how young/immature
# eg ọboba piẹpiẹ = Unripe ; Undeveloped.
# Piọpiọpiọ……(adj) Pointed and sharp e.g. nail
# Prarara……..(adj) Describes the sudden and forceful
# gushing out of blood or liquid.
# 44
#
# --- Page 45 ---
# Putuku or Pitiki … (adj) Describes quantity e.g. number
# of oranges fallen down from a tree.
# PH
# Phaphọ……………………… Measure it
# Phavwẹ………………………. Meet me
# Phẹghẹphẹghẹ…………….. Flat ; not thick
# Phihọ………………………….Add to it
# Phiọphiọ…………………….Straight
# Pho…………………………….Jump
# 45
#
# --- Page 46 ---
# Phopho……………………….. Blow it
# Phọphọ………………………. Disgrace him/her
# Phoro………………………….. Erase
# Phio…………………………….Stone it
# Phiọ……………………………. Straighten it. Make it straight
# R
# Ra …………………………… Go there
# Rara…………………………. Crawl e.g. snails crawl
# Rare………………………….. Lick; Use of Finger or Tongue
# to wipe-in/eat food like a dog
# Rẹ…………………………….. Beg
# 46
#
# --- Page 47 ---
# Re……………………………… Eat
# Riemu………………………. Eat food
# Riẹre………………………... Knows
# Riẹriẹ………………………… Lure him/her
# Riọ́……………………………. Eat it
# Riọ̀………………… Foam up e.g. when opening soda can
# Ririe………………………….. Clean it ; Wipe up ; Wipe
# Rọ……………………………… Swallow ; Swallow it
# Roro…………………………… Think ; Think about it
# Ru……………………………… Do
# Ruiruo………………………... Work
# Ruo……………………………. Do it
# Ruọ…………………………… Go inside
# 47
#
# --- Page 48 ---
# RH
# Rhá…………………. Un-tie ; Loosen ; Un-tangle ; Un-do knot
# Rhà……………………... Fly
# Rhare…(rharọ)……... Paint ; Plaster ;Smoothen
# Rharhọ ……………… Bore a hole in it
# Rhariẹ…………… Re-Kindle ;Hurt an existing sore/pain
# Rhẹrẹ…………………. Watchfulness ; Spying on
# Rhẹrhẹ……………….. Swim
# Rhẹriẹ………………… Change ; Turn around ;Turn it over.
# Rhẹrioma…………….Change anatomical position ; Turn a
# different direction ; Lie face up.
# Rhiọ……………………Start early ; Wake up early to begin
# Rhiri…………………. For a long time
# Rhirirhìrì…………… Forever.
# Rho…………… Pre-cook ; Not totally done ; Preservative
# partial cooking e.g. fresh meat or fish.
# Rhoma ta……… Say it again ; Repeat what you said
# Rhorha………………………. Hot
# 48
#
# --- Page 49 ---
# Rhuarho…………… Big.
# Rhuẹrẹ…………….. Repair ; Fix ; Make it better
# Rhuo…………. Weave e.g. as when weaving a basket.
# Rhuo………………. Put on your fashion gear ; Dress up.
# Rhurho…………… Cover it e.g. Cover a pot
# Rhurie……………… Rush ; uncontrollable population
# Movement ; unstoppable event.
# S
# Sa………………………… Shoot
# Sasa……………………. Agility ; Healthy and well ; Smart
# Sẹ………………………. Dress fashionably
# 49
#
# --- Page 50 ---
# Sẹ……………………… Efficacy of medication or treatment
# Se………………………. Call
# Sen……………………. Reject ; Refuse ; Say “no”
# Si…………………….. .. Write
# Siọ……………………….Reject it outright
# Sio……………………… Write it
# Sio……………………… Pull (towards self )
# Siomanu……………… Hide
# Sobọ………………….. Shake hands ; Shake my hand
# Su…………………….. Govern ; Rule ; Lead
# Suine……………. ……Sing a song
# SH
# She…………………………………… Fall
# 50
#
# --- Page 51 ---
# Shẹ………………………………….. Sell
# Shesheri…………………………… Very far
# Sherhẹ……………………… Lie down
# Shiguẹ…………… Greeting with the knees bent ; Kneel down
# Shoma………………………………. Advertise one’s self
# Shọrọ………………………………. Crawl
# T
# 51
#
# --- Page 52 ---
# Ta……………………. Say it ; Confess
# Ta………………… A mild condemnation ; Blame or curse
# Takẹ………………. Tell him/her
# Tit
# ẹ…………. …… Famous ; Popular
# Tọ………………….. Live long
# Tó…̣ ……………….. Dig it e.g. a pit or hole
# Tó…̣ …………………Fry it e.g. Gari
# Tọrọ…………………Pick ; Pick it
# Toro………………… Contribute
# Tota…………………Speak ; Talk
# Tua…………………. Chase him/her /it
# Tuato……………Chew on your chewing stick
# Tuatua…………… Strong and fearful
# Tue…………… Shake it off e.g. cloth that falls on dirt
# Tuọ………………… Chew it
# 52
#
# --- Page 53 ---
# U
# Ubeku……………………….. Bone
# Ubi…………………………….. Punch ; Knot
# Ubiako…………………….. Tooth
# Uchuhru……………………. Stump
# Uchuru………….. Products of animal husbandary ;
# raised birds and animals for food
# Udidẹ………………………. Earthworm
# Udi…………………………… Liquor
# Údi………………………….. Grass cutter
# 53
#
# --- Page 54 ---
# Udio………………………… Cover ; Cork ; Cap
# Udju………………………… Farm
# Udu………………………… Chest
# Ufi………………………… Trap
# Ufi……………………….. Rope ( also called uruhrẹ )
# Ufo………… Work that a person does for someone
# as repayment for the help that he had
# earlier received from that individual.
# Ufuna …………………………. Bamboo-made cigarette pipe
# Ufuoma………………………. Peace ; A state of serenity.
# Ugbakara…………………. Ladder
# Ugbenu……………………… Hill
# Ugbidu…………………….. Cocoyam farm
# Ugbudia……………………. Horse tail ; Ox tail
# Ugbunu……………………. Mouth
# Ughẹghẹ………………… Foolishness
# 54
#
# --- Page 55 ---
# Ughẹrughẹ…………….. Miniature bell
# Uje……………………………Twenty
# Uji………………………….. Stealing ; Thievery (Oji=Thieve)
# Ujori………………………. One hundred
# Ujuvẹ……………………. Forty
# Ukiri……………………… Drum
# Ukodo………………….. Porridge
# Úkóko…………………. Group ; Association
# Ukoko………………….. Tobacco pipe
# Ukoro………………….. Elephant tusk bangle
# Ukpokpo…… Missile ; Any object thrown at a target.
# Ukpono……………………… Cripple
# Ukuta………………….. Stone
# Umẹ…………………… Committee
# Une……………………… Song
# Unu…………………….. Hole ; mouth
# Unuebo………… Shout : to express surprise or for help
# 55
#
# --- Page 56 ---
# Unurhoro……………. Door entrance
# Upho…………………… Throat
# Uri………………………. Two hundred
# Uroko………………….. A mile
# Urhe……………………. Tree
# Urhi……………………. Law
# Urhiabọ……………… Finger
# Urhiawọ…………….. Toe
# Urhie………………….. Sea/river/ocean
# Urhiẹ…………………… Line
# Urhuẹ………………… Place of abode
# Urhurhu……………… Tail
# Urhuru………………. Voice
# Uri…………………….. Two hundred
# Uriri…………………… Glory
# Uruemu……………… Character ; Behavior
# u
# ruhrẹ…………….. Rope ; Cord ; Stem of some
# 56
#
# --- Page 57 ---
# creepers/climbers used as rope.
# Ushurhe……………. Axe
# Usí…………………….. Starch
# Usi…………………….. Popularity
# Úsi…………………… Line
# Usiamé…………… Well-water fetching rope
# Usiavwrẹ………… Key
# Utiẹn……………… Orange
# Utitẹ……………….. Seal ; Stamp & seal in Notary
# Utughẹ
# ……………. Hut
# Utuoma……………. Hatred
# Ututa……………… Onion
# Uvi………………….Paddle
# Uvwẹ……………Space
# Uvworo……… Feather
# Uyonta …………Truth
# Uyonvwi……… Head
# 57
#
# --- Page 58 ---
# V
# Va……… Slaughter ; Skin an animal ; Split e.g. kola nut
# Va……… Shout loud
# Vame…. Fetch water
# Ve…….
# Haggle the price e.g. asking for a lower price
# Vẹn……. Bend it
# Viẹ……. Weep ; Cry ; Grief
# Vie…….. Suck e.g. A child sucks the mother’s breast
# Vie……………. Older than ( vie we = older than you )
# Vievie………… Suck breast
# Vo……………… Fetch e.g. water
# Vọ…………….. Full
# Vuẹ…………… Tell him/her
# 58
#
# --- Page 59 ---
# Vughe……….. Recognise
# Vuo…………… Uproot ; Harvest
# Vurho………… .Un organized competition to acquire ;
# Scramble for ; un-healthy competition
# Vuvwo………… Roast ; Preserve by drying .
# Vrẹ …………… Get up
# Vrẹ mudia…… Stand up
# VW
# Vwarhe…………………………. Struggle
# 59
#
# --- Page 60 ---
# Vwariẹ………………………….. Shiver ; Shivering
# Vwariẹ́…………………………. Repeat it
# Vwavwó…̣ ……………………. Measure it
# Vwẹ……………………………. Urinate
# Vwiẹ…………………………… Deliver e.g. baby ; Bear a child
# Vwẹghẹvwẹghẹ………… Very thin and flat ; Not thick
# Vwerhe……………………… Sweet
# Vwerhẹ…………………….. Sleep
# Vwẹriẹ…………………….. Stop by ; Branch (while going on)
# Vwirhi………………………Break ; separate into two more pieces
# Vwio………………… Throw missiles at a target ; Stoning .
# Vwioro………………………….Droop
# Vwo………………………. …….Jump
# Vwó…………………….. ……. Own ; Own it = Vwóró
# Vworho………… … ………Sift it
# Vworó………….. ……. …Erase it
# Vworovworo……….. …….Smooth
# Vwovwo………Blow a wood or charcoal fire with the mouth
# 60
#
# --- Page 61 ---
# Vwravwra…… Restlessness ; uneasiness ; Impatient
# Vwrovwro…Unhealthy competition ; Fierce rivalry ; Jealousy
# W
# Wado………………………………….. Greeting to you all
# Wẹ………………………………………. You
# Wẹwẹ…………………………………. Yourself
# Wian……………………………………. Do the work
# Wiowian……………………………… Work
# Wonro…………………… Pluck out e.g. seeds from bunches of fruits
# Wran…………………………………… Defrost ; Liquefy ; Heat solidified oil
# back to its liquid form.
# 61
#
# --- Page 62 ---
# Y
# Yan…………………………….. Walk
# Yanra………................... Go away
# Yanrhe……………………….. Come
# Yare…………………………… Bitter
# Yare…………………………..Borrow ; Beg for your need
# Yerakpọ……………………. Live your life
# Yere…………………………… Greet him/her
# Yẹrẹ…………………………. Or
# Yeri…………………………… Climb
# Yoma…………………………. Boast
# Yõma…………………………. Good
# Yon……………………………. Hear
# 62
#
# --- Page 63 ---
# Yonrẹ……………………….. Hear my pleading/prayer
# Yorho………………………… Eliminating water with a bucket,
# basin or by mechanical means.
# Yoro…………………………..Pull out ; Pull off
# Yọrọ……………………… Hold it
# Yonvwe……………………Hear me
# Yọnrhe……………………Smell
# Z
# Ze……………………………………. Sacrifice ( for a god )
# Zighizighi…………………………. Rough ; Disorganized
# 63
#
# --- Page 64 ---
# Zigho ……………………………… Disorganize it ; Scatter the arrangement.
# Ziọziọ …………………………….. Sluggish
# Zọrọkọ……………………………. An adjective describing how tall and .
# beautiful a person is. e.g Aye na vwa
# zọrọkọ= The woman is tall and beautiful.
# 64

# %%
pdf_path = "Urhobo_Dictionary_by_Ebireri_Okrokoto_Ur.pdf"
all_tables = []

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        table = page.extract_table()
        if table:
            df = pd.DataFrame(table[1:], columns=table[0])
            all_tables.append(df)

if all_tables:
    combined_df = pd.concat(all_tables, ignore_index=True)
    print(combined_df.head())
else:
    print("No tables found.")
# Out:
# No tables found.

# %%
pdf_path = "Urhobo_Dictionary_by_Ebireri_Okrokoto_Ur.pdf"
entries = []

with pdfplumber.open(pdf_path) as pdf:
    for page_num in [0, 1]:  # pages 1 and 2 (0-indexed)
        page = pdf.pages[page_num]
        table = page.extract_table()
        
        if table:
            header = table[0]
            rows = table[1:]  # skip header row if necessary

            # Try to detect Urhobo and English column positions
            urhobo_idx = None
            english_idx = None

            for i, col in enumerate(header):
                if col and "urhobo" in col.lower():
                    urhobo_idx = i
                if col and "english" in col.lower():
                    english_idx = i

            if urhobo_idx is not None and english_idx is not None:
                for row in rows:
                    if row:
                        urhobo_word = row[urhobo_idx]
                        english_word = row[english_idx]
                        entries.append((urhobo_word, english_word))
            else:
                print(f"Could not detect Urhobo or English columns on page {page_num + 1}")
        else:
            print(f"No table found on page {page_num + 1}")

# Convert to DataFrame
df = pd.DataFrame(entries, columns=["Urhobo", "English"])
print(df.head())
# Out:
# No table found on page 1
# No table found on page 2
# Empty DataFrame
# Columns: [Urhobo, English]
# Index: []

# %%
pdf_path = "Urhobo_Dictionary_by_Ebireri_Okrokoto_Ur.pdf"
entries = []
with pdfplumber.open(pdf_path) as pdf:
    for page_num in [3, 4]:  # pages 4 and 5 (0-based indexing)
        page = pdf.pages[page_num]
        text = page.extract_text()

        if text:
            lines = text.split("\n")
            for line in lines:
                parts = line.strip().split()

                # Only process lines with at least 2 words
                if len(parts) >= 2:
                    urhobo = parts[0]
                    english = " ".join(parts[2:]) if len(parts) > 2 else parts[1]
                    entries.append((urhobo, english))
        else:
            print(f"No text found on page {page_num + 1}")

# Convert to DataFrame
df = pd.DataFrame(entries, columns=["Urhobo", "English"])
print(df.head())
# Out:
#                Urhobo                                            English
# 0                 Aha                     …………………….. A shout of surprise
# 1              Ahanre  called IKPEKPA )……Lower deck of fireplace plat...
# 2    Ahe…………………………………                                                owl
# 3  Ahwa………………………………..                 beaked non climbing giant squirrel
# 4   Aka……………………………………                       people from southern Nigeria

# %%
pdf_path = "Urhobo_Dictionary_by_Ebireri_Okrokoto_Ur.pdf"

with pdfplumber.open(pdf_path) as pdf:
    page = pdf.pages[3]  # Example: page 4
    text = page.extract_text()
    
    if text:
        lines = text.split("\n")
        print("Raw lines on page 4:")
        for i, line in enumerate(lines):
            print(f"{i}: {line}")
# Out:
# Raw lines on page 4:
# 0: Aha ! …………………….. A shout of surprise
# 1: Ahanre (also called IKPEKPA )……Lower deck of fireplace platform.
# 2: Ahe………………………………… Night owl
# 3: Ahwa……………………………….. A beaked non climbing giant squirrel
# 4: Aka…………………………………… Edo people from southern Nigeria
# 5: Áká………………………………….. Bitter kola
# 6: Akaunọrọ……………………. Lizard
# 7: Ako…………………………………… Tooth
# 8: Akoroda……………………………. Cutlass sheath.
# 9: Akpãkpa……………………… Mat woven out of palm branch back
# 10: Akpakpasimagha ……………… Scorpion
# 11: Akpanurhe…………………………. Local Low seat
# 12: Àkp
# 13: é
# 14: rẹ̀…
# 15: …………………… Bull horn
# 16: Akpẹ …………………….Padlock ; Bird’s gizzard ; container of items
# 17: Akpẹrẹ………………… Basket
# 18: Akpẹtẹ…………………. Chief cook ; cook
# 19: Akpine…………………. Lead singer
# 20: Akpọ…………………… World ; earth ; life
# 21: Akpono………………… Plastic beads for female fashion.
# 22: Ame……………………. Water
# 23: 4

# %%
with pdfplumber.open(pdf_path) as pdf:
    for page_num in [3, 4]:  # Pages 4 and 5
        page = pdf.pages[page_num]
        text = page.extract_text()

        if text:
            lines = text.split("\n")
            
            # ✅ Skip the first line (assumed to be the header)
            for line in lines[1:]:
                parts = line.strip().split()

                if len(parts) >= 2:
                    urhobo = parts[0]
                    english = " ".join(parts[2:]) if len(parts) > 2 else parts[1]
                    entries.append((urhobo, english))
        else:
            print(f"No text found on page {page_num + 1}")

# Convert to DataFrame
df = pd.DataFrame(entries, columns=["Urhobo", "English"])
print(df.head())
# Out:
#                Urhobo                                            English
# 0                 Aha                     …………………….. A shout of surprise
# 1              Ahanre  called IKPEKPA )……Lower deck of fireplace plat...
# 2    Ahe…………………………………                                                owl
# 3  Ahwa………………………………..                 beaked non climbing giant squirrel
# 4   Aka……………………………………                       people from southern Nigeria

# %%
pdf_path = "Urhobo_Dictionary_by_Ebireri_Okrokoto_Ur.pdf"
entries = []

with pdfplumber.open(pdf_path) as pdf:
    for page_num in range(3, 53):  # pages 4 to 53 inclusive
        page = pdf.pages[page_num]
        text = page.extract_text()

        if text:
            lines = text.split("\n")
            
            # Skip first line (header) on each page
            for line in lines[1:]:
                parts = line.strip().split()

                if len(parts) >= 2:
                    urhobo = parts[0]
                    english = " ".join(parts[2:]) if len(parts) > 2 else parts[1]
                    entries.append((urhobo, english))
        else:
            print(f"No text found on page {page_num + 1}")

# Convert to DataFrame
df = pd.DataFrame(entries, columns=["Urhobo", "English"])
print(df.head())

# Save to CSV
df.to_csv("urhobo_english_pages_4_to_53.csv", index=False)
# Out:
#                Urhobo                                            English
# 0              Ahanre  called IKPEKPA )……Lower deck of fireplace plat...
# 1    Ahe…………………………………                                                owl
# 2  Ahwa………………………………..                 beaked non climbing giant squirrel
# 3   Aka……………………………………                       people from southern Nigeria
# 4  Áká…………………………………..                                               kola

# %%
### To clean the data

# %%
df = df.dropna()
df = df[(df["Urhobo"].str.strip() != "") & (df["English"].str.strip() != "")]

# %%
def clean_text(text):
    text = text.lower().strip()                      # Lowercase & trim spaces
    text = re.sub(r"[^\w\s'-]", '', text)            # Remove punctuation except apostrophes & hyphens
    text = re.sub(r"\s+", " ", text)                 # Normalize multiple spaces
    return text

df["Urhobo"] = df["Urhobo"].apply(clean_text)
df["English"] = df["English"].apply(clean_text)

# %%
df = df.drop_duplicates()

# %%
df = df[(df["Urhobo"].str.len() > 1) & (df["English"].str.len() > 1)]
df = df[(df["Urhobo"].str.len() < 100) & (df["English"].str.len() < 100)]

# %%
### To export

# %%
df["Urhobo"].to_csv("urhobo.txt", index=False, header=False)
df["English"].to_csv("english.txt", index=False, header=False)

# %%
df.to_csv("urhobo_english_corpus.csv", index=False)
